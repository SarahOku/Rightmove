# %%
from Rightmove import Scraper
import pandas as pd
bot = Scraper()
bot.accept_cookies()
bot.input_location_to_search_bar('Manchester')
bot.display_data()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 105.0.5195
# Get LATEST chromedriver version for 105.0.5195 google-chrome
# Driver [/Users/sarahokuyemi/.wdm/drivers/chromedriver/mac64_m1/105.0.5195.52/chromedriver] found in cache
#                                                  Link       Price Bedrooms  \
# 0   https://www.rightmove.co.uk/properties/1277808...    £140,000      N/A
# 1   https://www.rightmove.co.uk/properties/1217204...  £3,500,000      N/A
# 2   https://www.rightmove.co.uk/properties/1272227...  £2,950,000      N/A
# 3   https://www.rightmove.co.uk/properties/7213014...  £2,750,000      N/A
# 4   https://www.rightmove.co.uk/properties/1273835...  £2,750,000      N/A
# 5   https://www.rightmove.co.uk/properties/1199641...  £2,750,000      N/A
# 6   https://www.rightmove.co.uk/properties/1237572...  £2,750,000      N/A
# 7   https://www.rightmove.co.uk/properties/1272745...  £2,500,000      N/A
# 8   https://www.rightmove.co.uk/properties/1183131...  £2,500,000      N/A
# 9   https://www.rightmove.co.uk/properties/1276722...  £1,900,000      N/A
# 10  https://www.rightmove.co.uk/properties/1224422...  £1,750,000      N/A
# 11  https://www.rightmove.co.uk/properties/1277922...  £1,750,000      N/A
# 12  https://www.rightmove.co.uk/properties/1251130...  £1,695,000      N/A
# 13  https://www.rightmove.co.uk/properties/8570205...  £1,600,000      N/A
# 14  https://www.rightmove.co.uk/properties/1270225...  £1,585,000      N/A
# 15  https://www.rightmove.co.uk/properties/1253824...  £1,525,000      N/A
# 16  https://www.rightmove.co.uk/properties/1271705...  £1,500,000      N/A
# 17  https://www.rightmove.co.uk/properties/8555146...  £1,500,000      N/A
# 18  https://www.rightmove.co.uk/properties/1249743...  £1,500,000      N/A
# 19  https://www.rightmove.co.uk/properties/1275924...  £1,500,000      N/A
# 20  https://www.rightmove.co.uk/properties/1277312...  £1,500,000      N/A
# 21  https://www.rightmove.co.uk/properties/1140627...  £1,500,000      N/A
# 22  https://www.rightmove.co.uk/properties/8570200...  £1,300,000      N/A
# 23  https://www.rightmove.co.uk/properties/1247938...  £1,299,950      N/A
# 24  https://www.rightmove.co.uk/properties/8581596...  £1,250,000      N/A
#
#    Sqft Date Added
# 0   N/A        N/A
# 1   N/A        N/A
# 2   N/A        N/A
# 3   N/A        N/A
# 4   N/A        N/A
# 5   N/A        N/A
# 6   N/A        N/A
# 7   N/A        N/A
# 8   N/A        N/A
# 9   N/A        N/A
# 10  N/A        N/A
# 11  N/A        N/A
# 12  N/A        N/A
# 13  N/A        N/A
# 14  N/A        N/A
# 15  N/A        N/A
# 16  N/A        N/A
# 17  N/A        N/A
# 18  N/A        N/A
# 19  N/A        N/A
# 20  N/A        N/A
# 21  N/A        N/A
# 22  N/A        N/A
# 23  N/A        N/A
# 24  N/A        N/A

# %%
from Rightmove import Scraper
import pandas as pd
bot = Scraper()
bot.accept_cookies()
bot.input_location_to_search_bar('Manchester')
bot.collect_prop_data()

def display_data(self):
        data_display = self.collect_prop_data()
        #pd.(0, 'ID', range(880, 880 + len(pd)))
    return pd.DataFrame(data_display)
# Out:
#   File <tokenize>:11
#     return pd.DataFrame(data_display)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sarahokuyemi/Desktop/WebScraping/WebScraperProj/test.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/sarahokuyemi/Desktop/WebScraping/WebScraperProj/test.ipynb#ch0000004?line=0'>1</a> df.insert(0, 'ID', range(880, 880 + len(df)))
#
# NameError: name 'df' is not defined

# %%
id = range(1,50,1)
print(id)
# Out:
# range(1, 50)
